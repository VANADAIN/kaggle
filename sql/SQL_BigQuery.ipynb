# %% [markdown]
# **[SQL Home Page](https://www.kaggle.com/learn/intro-to-sql)**
#
# ---

# %% [markdown]
# # Introduction
#
# The first test of your new data exploration skills uses data describing crime in the city of Chicago.
#
# Before you get started, run the following cell. It sets up the automated feedback system to review your answers.

# %%
# Set up feedack system
from learntools.core import binder
binder.bind(globals())
from learntools.sql.ex1 import *
print("Setup Complete")
# Out:
# Using Kaggle's public dataset BigQuery integration.
# Setup Complete

# %% [markdown]
# Use the next code cell to fetch the dataset.

# %%
from google.cloud import bigquery

# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "chicago_crime" dataset
dataset_ref = client.dataset("chicago_crime", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)
# Out:
# Using Kaggle's public dataset BigQuery integration.

# %% [markdown]
# # Exercises
#
# ### 1) Count tables in the dataset
#
# How many tables are in the Chicago Crime dataset?

# %%
# Write the code you need here to figure out the answer
tables = list(client.list_tables(dataset))

# %%
num_tables = len(tables)  # Store the answer as num_tables and then run this cell

q_1.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_1.hint()
#q_1.solution()

# %% [markdown]
# ### 2) Explore the table schema
#
# How many columns in the `crime` table have `TIMESTAMP` data?

# %%
# Write the code to figure out the answer
table_ref = dataset_ref.table('crime')
table = client.get_table(table_ref)
df = client.list_rows(table, max_results=5).to_dataframe()
df
# Out:
#    unique_key case_number                      date                block  \
# 0     2368652    HH671227 2002-08-01 00:00:00+00:00   093XX S COLFAX AVE
# 1    10301639    HY145626 2015-02-09 14:15:00+00:00   052XX S PULASKI RD
# 2    10342568    HY499495 2015-11-12 21:46:57+00:00  033XX S WESTERN AVE
# 3    10608533    HZ360820 2013-09-09 00:00:00+00:00   092XX S DREXEL AVE
# 4     2415645    HH713917 2002-10-14 16:25:00+00:00    067XX W GRAND AVE
#
#    iucr                primary_type                          description  \
# 0  1751  OFFENSE INVOLVING CHILDREN         CRIM SEX ABUSE BY FAM MEMBER
# 1  2014                   NARCOTICS         MANU/DELIVER: HEROIN (WHITE)
# 2  2028                   NARCOTICS                POSS: SYNTHETIC DRUGS
# 3  1153          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 4  0530                     ASSAULT        AGGRAVATED: OTHER DANG WEAPON
#
#              location_description  arrest  domestic  ...  ward  \
# 0                       APARTMENT   False     False  ...     7
# 1  PARKING LOT/GARAGE(NON.RESID.)    True     False  ...    23
# 2                       RESIDENCE    True     False  ...    12
# 3                       RESIDENCE   False     False  ...     8
# 4                          STREET   False     False  ...    36
#
#    community_area  fbi_code  x_coordinate y_coordinate  year  \
# 0              48        20          None         None  2002
# 1              62        18          None         None  2015
# 2              59        18          None         None  2015
# 3              47        11          None         None  2013
# 4              18       04A          None         None  2002
#
#                  updated_on  latitude longitude location
# 0 2015-08-17 15:03:40+00:00      None      None     None
# 1 2016-06-25 15:50:05+00:00      None      None     None
# 2 2016-07-16 15:45:53+00:00      None      None     None
# 3 2016-07-23 15:50:11+00:00      None      None     None
# 4 2015-08-17 15:03:40+00:00      None      None     None
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['unique_key', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic', 'beat',
#        'district', 'ward', 'community_area', 'fbi_code', 'x_coordinate',
#        'y_coordinate', 'year', 'updated_on', 'latitude', 'longitude',
#        'location'],
#       dtype='object')

# %%
num_timestamp_fields = 2 # Put your answer here

q_2.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_2.hint()
#q_2.solution()

# %% [markdown]
# ### 3) Create a crime map
#
# If you wanted to create a map with a dot at the location of each crime, what are the names of the two fields you likely need to pull out of the `crime` table to plot the crimes on a map?

# %%
# Write the code here to explore the data so you can find the answer

# %%
fields_for_plotting = ['latitude', 'longitude'] # Put your answers here

q_3.check()
# Out:
# Incorrect: There are two fields or variables that are commonly used to plot things on maps. ['latitude', 'longtitude'] is not exactly right

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_3.hint()
#q_3.solution()
# Out:
# Solution:
# ```python
# fields_for_plotting = ['latitude', 'longitude']
# ```

# %% [markdown]
# Thinking about the question above, there are a few columns that appear to have geographic data. Look at a few values (with the `list_rows()` command) to see if you can determine their relationship.  Two columns will still be hard to interpret. But it should be obvious how the `location` column relates to `latitude` and `longitude`.

# %%
# Scratch space for your code

# %% [markdown]
# # Keep going
#
# You've looked at the schema, but you haven't yet done anything exciting with the data itself. Things get more interesting when you get to the data, so keep going to **[write your first SQL query](https://www.kaggle.com/dansbecker/select-from-where).**

# %% [markdown]
# ---
# **[SQL Home Page](https://www.kaggle.com/learn/intro-to-sql)**
#
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum) to chat with other Learners.*
